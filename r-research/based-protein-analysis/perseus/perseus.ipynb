# %%
import pandas as pd

# %%
perseus_no_normalization_imputation_normal_distribution = pd.read_csv("./perseus_no_normalization_imputation_normal_distribution.txt", header=0, sep="\t")
perseus_no_normalization_imputation_normal_distribution.dropna(subset=["Student's T-test Difference 1_2", "Student's T-test q-value 1_2"], how="any", inplace=True)
positive =  perseus_no_normalization_imputation_normal_distribution[(abs(perseus_no_normalization_imputation_normal_distribution["Student's T-test Difference 1_2"]) >1) &(perseus_no_normalization_imputation_normal_distribution["Student's T-test q-value 1_2"] <0.05) ]
negative = perseus_no_normalization_imputation_normal_distribution[(abs(perseus_no_normalization_imputation_normal_distribution["Student's T-test Difference 1_2"]) <=1) | (perseus_no_normalization_imputation_normal_distribution["Student's T-test q-value 1_2"] >=0.05) ]

no_difference_ups = ["P00167", "P01133", "P02144", "P04040", "P15559", "P62937", "P63165",  "Q06830"]

difference_ups =  ["P01579", "O76070", "P63279", "P68871","P01127", "P01008", "P62988", "P10599", "P02787", "P99999", "P12081", "P51965","P10636-8", 
       "P01031", "P09211", "P02788", "P41159", "O00762", "P05413", "P00441", "P00918", "P08758", "P00915", "P01344", "P69905", 
        "P00709", "P55957", "P08263", "P61769", "P10145", "P16083", "P61626", "P02741", "P06732",
        "P01375", "P06396", "P02753", "P01112", "Q15843", "P02768"]

TP = len(positive[positive["Majority protein IDs"].str.contains("|".join(difference_ups))])
FP = len(positive) - TP

FN = len(negative[negative["Majority protein IDs"].str.contains("|".join(difference_ups))])
TN = len(negative) - FN

print(TP)
print(FP)
print(TN)
print(FN)
# Out:
# 38
# 2
# 1906
# 0

# %%
negative[negative["Majority protein IDs"].str.contains("UPS")]
# Out:
#     LFQ intensity UPS1_01  LFQ intensity UPS1_02  LFQ intensity UPS1_03  \
# 2               33.559898              33.266960              33.075001
# 11              29.016855              29.932133              29.928606
# 15              33.358490              32.575199              32.614346
# 20              34.735195              34.602779              34.665272
# 37              32.099018              32.514065              32.246151
# 44              33.799332              33.732166              33.686249
#
#     LFQ intensity UPS1_04  LFQ intensity UPS2_01  LFQ intensity UPS2_02  \
# 2               32.754719              32.345196              32.051254
# 11              30.662548              29.065044              29.396931
# 15              32.391178              31.315218              31.481546
# 20              34.443321              33.732773              33.684471
# 37              32.574070              31.624664              31.132038
# ...

# %%
perseus_no_normalization_imputation_normal_distribution = pd.read_csv("./no_normalization_imputation_NaN.txt", header=0, sep="\t")
perseus_no_normalization_imputation_normal_distribution.dropna(subset=["Student's T-test Difference 1_2", "Student's T-test q-value 1_2"], how="any", inplace=True)
positive =  perseus_no_normalization_imputation_normal_distribution[(abs(perseus_no_normalization_imputation_normal_distribution["Student's T-test Difference 1_2"]) >1) &(perseus_no_normalization_imputation_normal_distribution["Student's T-test q-value 1_2"] <0.05) ]
negative = perseus_no_normalization_imputation_normal_distribution[(abs(perseus_no_normalization_imputation_normal_distribution["Student's T-test Difference 1_2"]) <=1) | (perseus_no_normalization_imputation_normal_distribution["Student's T-test q-value 1_2"] >=0.05) ]

no_difference_ups = ["P00167", "P01133", "P02144", "P04040", "P15559", "P62937", "P63165",  "Q06830"]

difference_ups =  ["P01579", "O76070", "P63279", "P68871","P01127", "P01008", "P62988", "P10599", "P02787", "P99999", "P12081", "P51965","P10636-8", 
       "P01031", "P09211", "P02788", "P41159", "O00762", "P05413", "P00441", "P00918", "P08758", "P00915", "P01344", "P69905", 
        "P00709", "P55957", "P08263", "P61769", "P10145", "P16083", "P61626", "P02741", "P06732",
        "P01375", "P06396", "P02753", "P01112", "Q15843", "P02768"]

TP = len(positive[positive["Majority protein IDs"].str.contains("|".join(difference_ups))])
FP = len(positive) - TP

FN = len(negative[negative["Majority protein IDs"].str.contains("|".join(difference_ups))])
TN = len(negative) - FN

print(TP)
print(FP)
print(TN)
print(FN)
# Out:
# 27
# 2
# 1906
# 1

# %%
negative[negative["Majority protein IDs"].str.contains("UPS")]
# Out:
#     LFQ intensity UPS1_01  LFQ intensity UPS1_02  LFQ intensity UPS1_03  \
# 0               32.560608              32.876701              32.943443
# 2               33.559898              33.266960              33.075001
# 11              29.016855              29.932133              29.928606
# 15              33.358490              32.575199              32.614346
# 20              34.735195              34.602779              34.665272
# 37              32.099018              32.514065              32.246151
# 44              33.799332              33.732166              33.686249
#
#     LFQ intensity UPS1_04  LFQ intensity UPS2_01  LFQ intensity UPS2_02  \
# 0               32.584213                    NaN              25.527281
# 2               32.754719              32.345196              32.051254
# 11              30.662548              29.065044              29.396931
# 15              32.391178              31.315218              31.481546
# ...

# %%
perseus_no_normalization_imputation_normal_distribution = pd.read_csv("./perseus_no_normalization_imputation_0.txt", header=0, sep="\t")
perseus_no_normalization_imputation_normal_distribution.dropna(subset=["Student's T-test Difference 1_2", "Student's T-test q-value 1_2"], how="any", inplace=True)
positive =  perseus_no_normalization_imputation_normal_distribution[(abs(perseus_no_normalization_imputation_normal_distribution["Student's T-test Difference 1_2"]) >1) &(perseus_no_normalization_imputation_normal_distribution["Student's T-test q-value 1_2"] <0.05) ]
negative = perseus_no_normalization_imputation_normal_distribution[(abs(perseus_no_normalization_imputation_normal_distribution["Student's T-test Difference 1_2"]) <=1) | (perseus_no_normalization_imputation_normal_distribution["Student's T-test q-value 1_2"] >=0.05) ]

no_difference_ups = ["P00167", "P01133", "P02144", "P04040", "P15559", "P62937", "P63165",  "Q06830"]

difference_ups =  ["P01579", "O76070", "P63279", "P68871","P01127", "P01008", "P62988", "P10599", "P02787", "P99999", "P12081", "P51965","P10636-8", 
       "P01031", "P09211", "P02788", "P41159", "O00762", "P05413", "P00441", "P00918", "P08758", "P00915", "P01344", "P69905", 
        "P00709", "P55957", "P08263", "P61769", "P10145", "P16083", "P61626", "P02741", "P06732",
        "P01375", "P06396", "P02753", "P01112", "Q15843", "P02768"]

TP = len(positive[positive["Majority protein IDs"].str.contains("|".join(difference_ups))])
FP = len(positive) - TP

FN = len(negative[negative["Majority protein IDs"].str.contains("|".join(difference_ups))])
TN = len(negative) - FN

print(TP)
print(FP)
print(TN)
print(FN)
# Out:
# 31
# 2
# 1906
# 7
